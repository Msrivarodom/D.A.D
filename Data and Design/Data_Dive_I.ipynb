# %% [markdown]
# This data was obtained from the NYC Open Data website with dataset information released by the Department of Education. It runs from 2005 - 2011 and it's purpose is to display the graduation or dropout outcomes of students based on qualitative and quantitave variables. The main variables being: Borough and Ethnicity.

# %%
# %matplotlib inline 
import matplotlib as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('data/2005_-_2011_Graduation_Outcomes_-_Borough_-_Ethnicity.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 23 columns):
# Borough                               440 non-null object
# Cohort Year                           440 non-null int64
# Cohort Category                       440 non-null object
# Demographic                           440 non-null object
# Total Cohort Num                      440 non-null object
# Total Grads Num                       440 non-null object
# Total Grads Pct of cohort             440 non-null object
# Total Regents Num                     440 non-null object
# Total Regents Pct of cohort           440 non-null object
# Total Regents Pct of grads            440 non-null object
# Advanced Regents Num                  440 non-null object
# Advanced Regents Pct of cohort        440 non-null object
# Advanced Regents Pct of grads         440 non-null object
# Regents w/o Advanced Num              440 non-null object
# ...

# %%
df.head()
# Out:
#   Borough  Cohort Year Cohort Category Demographic Total Cohort Num  \
# 0   Bronx         2001    4 Year  June       Asian              638
# 1   Bronx         2001          5 Year       Asian              638
# 2   Bronx         2001          6 Year       Asian              638
# 3   Bronx         2002    4 Year  June       Asian              681
# 4   Bronx         2002          5 Year       Asian              681
#
#   Total Grads Num Total Grads Pct of cohort Total Regents Num  \
# 0             479                    75.10%               396
# 1             528                    82.80%               416
# 2             534                    83.70%               416
# 3             497                    73.00%               451
# 4             564                    82.80%               473
#
#   Total Regents Pct of cohort Total Regents Pct of grads  \
# 0                      62.10%                     82.70%
# 1                      65.20%                     78.80%
# ...

# %%
df.groupby('Borough')

# %%
Borough.first()
# Out:
#                Cohort Year Cohort Category Demographic Total Cohort Num  \
# Borough
# Bronx                 2001    4 Year  June       Asian              638
# Brooklyn              2001    4 Year  June       Asian            2,418
# Manhattan             2001    4 Year  June       Asian            1,581
# Queens                2001    4 Year  June       Asian            4,222
# Staten Island         2001    4 Year  June       Asian              333
#
#               Total Grads Num Total Grads Pct of cohort Total Regents Num  \
# Borough
# Bronx                     479                    75.10%               396
# Brooklyn                1,543                    63.80%             1,305
# Manhattan               1,265                    80.00%             1,038
# Queens                  2,836                    67.20%             2,258
# Staten Island             268                    80.50%               225
#
# ...

# %%
df['Cohort Year'].hist()

# %%
df[['Total Grads Num', 'Demographic']].describe()
# Out:
#        Total Grads Num Demographic
# count              440         440
# unique             408           4
# top                479       Asian
# freq                 3         110

# %%
df[['Cohort Year', 'Demographic']].boxplot()

# %% [markdown]
# There are 23 variables included in this dataset. The primary ones being borough, demographic, year, graduation total/percentage, dropout total/percentage. The DOE has to manually input each of these values, so there may be human error involved and inaccurate numbers. As well as, this data set is from 7 years ago. It may be hard to distiniguish if there is a relatuonship between borough and demographic to the drop out and graduation rate. I'm unsure of the percentages should be included altogther in this data set particulary, just because it gives it a bit of an added dimension that may not be needed. However, the DOE does include New York Students who took Regents or Advanced seeing if there is a relationship between ethnicity and academic merit. Jupyter ran many of the variables as categorial instead of quantitative. It found that from a sample size of 440 the top demographic that graduated was Asian.
