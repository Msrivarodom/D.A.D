# %% [markdown]
# Problem 1: What is the top rated red wine under eighteen dollars a bottle? Lowest rated white in the same price range? The top rated red wine was the Quinta do Portal 2007 Mural Reserva Red (Douro) from Portugal priced at ten dollars. Whereas the lowest rated white wine was the Seigneurs de Bergerac 1999 White (Bergerac) from France priced at eight dollars.

# %% [markdown]
# Problem 2: What reviewers were the most generous? The least? Describe your approach. The reviews that were the most generous seemed to be wines that reflected a lower price points, making for a higher scoring due to the representation of price. However, those that were fairly expensive -- if the wine did not taste good, or was not of a certain reviewer's standard the points given were low.

# %% [markdown]
# Problem 3:
# Performing df['name'] will result in a list of the names under the names column i.e Hennesey, Tino, Oden, LuLu.
#
# Performing df['color'].value_counts() results in the color (red, white, and yellow) alongside how many times it has been included in order. This would look like: Red 2, White 1, and Yellow 1.
#
# Performing df.nlargest(2, 'age') results in 2 rows which displays the 2 largest numbers in order. In this case it would be: (on top) 1 Hennesey age 12 speed 4.2 color red (on bottom) 3 Oden age 11 speed 5.5 color yellow.
#
# Performing df.describe() results in the the variable of age being a column with rows describing the age and speed column by: count, mean, std, min, 25%, 50%, 75%, and max.
#
# Performing df.groupby('Color')['age'].mean() results in the color being listed by the mean or average of the age that was included in the data.

# %% [markdown]
# 5 questions:
# 1) Which taster name did the most amount of reviews?
# 2) Which province had the least amount of points?
# 3) Which wine is the most expensive with the highest amount of points?
# 4) What was the average number of points total?
# 5) Which wine had the smallest number of points?

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/winemag-data-130k-v2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
# Unnamed: 0               129971 non-null int64
# country                  129908 non-null object
# description              129971 non-null object
# designation              92506 non-null object
# points                   129971 non-null int64
# price                    120975 non-null float64
# province                 129908 non-null object
# region_1                 108724 non-null object
# region_2                 50511 non-null object
# taster_name              103727 non-null object
# taster_twitter_handle    98758 non-null object
# title                    129971 non-null object
# variety                  129970 non-null object
# winery                   129971 non-null object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 13.9+ MB

# %%
df.nsmallest(1, 'points')
# Out:
#      Unnamed: 0 country                                        description  \
# 344         344   Chile  Aromas of pumpkin, squash and corn chips are s...
#
#       designation  points  price      province region_1 region_2  \
# 344  Gran Reserva      80   19.0  Leyda Valley      NaN      NaN
#
#            taster_name taster_twitter_handle  \
# 344  Michael Schachner           @wineschach
#
#                                                  title     variety  \
# 344  Viña Tarapacá 2015 Gran Reserva Chardonnay (Le...  Chardonnay
#
#             winery
# 344  Viña Tarapacá

# %%
df['points'].mean()
# Out:
# 88.44713820775404

# %%
df.groupby('province')['points'].nsmallest()
# Out:
# province
# Achaia                     101471    83
#                            52269     84
#                            72355     86
#                            112614    86
#                            107621    90
# Aconcagua Costa            13764     83
#                            88471     85
#                            14436     86
#                            27834     86
#                            60084     86
# Aconcagua Valley           79101     80
#                            92445     80
#                            61699     83
#                            79881     83
#                            63094     84
# Aegean                     42301     86
#                            42302     86
#                            53157     86
#                            66086     87
#                            127835    87
# Agioritikos                34284     86
#                            72354     86
#                            65238     87
# ...

# %%
df = pd.read_csv('data/winemag-data-130k-v2.csv')

# %%
pd.DataFrame(3 * np.random.rand(4, 2), index=['US', 'France', 'Italy', 'Portugal'], columns=['variety', 'points'])
# Out:
#            variety    points
# US        1.396566  2.217996
# France    1.329504  2.774758
# Italy     0.392066  1.913857
# Portugal  0.090185  1.473736

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1180c5eb8>,
# ...
#       dtype=object)

# %% [markdown]
# I went through the pandas tutorials about visualization. I learned about the use of indecies and columns in trying to visually portray any dataset. Initally, I wanted to make a pie chart. But I was having a hard time iterating on the code that was followed in the tutorial to match the wine data set. I wanted to have 2 pie charts that showed the variety of the wine and the points they received from 4 countries. The countries are listed above the histogram charts.

# %%
u18 = df[df['price'] <= 18]

# %%
u18.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
# 6           6     Italy  Here's a bright, informal red that opens with ...
#
#             designation  points  price           province  \
# 1              Avidagos      87   15.0              Douro
# 2                   NaN      87   14.0             Oregon
# 3  Reserve Late Harvest      87   13.0           Michigan
# 5          Ars In Vitro      87   15.0     Northern Spain
# 6               Belsito      87   16.0  Sicily & Sardinia
#
#               region_1           region_2         taster_name  \
# 1                  NaN                NaN          Roger Voss
# ...

# %%
u18.nlargest(15, 'points')
# Out:
#         Unnamed: 0   country  \
# 6267          6267        US
# 19136        19136     Spain
# 23974        23974  Portugal
# 39318        39318    France
# 69526        69526        US
# 84597        84597        US
# 88682        88682   Austria
# 98438        98438        US
# 123776      123776        US
# 3843          3843  Portugal
# 3844          3844     Italy
# 5509          5509   Austria
# 6932          6932  Portugal
# 9600          9600        US
# 9609          9609    France
#
#                                               description  \
# 6267    This tastes like a more concentrated and sweet...
# 19136   A spectacularly sweet and rich bruiser, and on...
# 23974   Assobio is from a single vineyard in the Quint...
# 39318   A rich, sweet wine that maintains complete fre...
# 69526   This dry Moscato Giallo from Lodi is delicious...
# 84597   A gorgeous, rich and aromatic Riesling, this i...
# 88682   A little air is all that is needed to shake th...
# ...

# %% [markdown]
# Problem 2:

# %%
df.groupby('taster_name')['points'].mean().sort_values(ascending = False)
# Out:
# taster_name
# Anne Krebiehl MW      90.562551
# Matt Kettmann         90.008686
# Virginie Boone        89.213379
# Mike DeSimone         89.101167
# Paul Gregutt          89.082564
# Kerin O’Keefe         88.867947
# Sean P. Sullivan      88.755739
# Roger Voss            88.708003
# Jim Gordon            88.626287
# Joe Czerwinski        88.536235
# Anna Lee C. Iijima    88.415629
# Jeff Jenssen          88.319756
# Christina Pickard     87.833333
# Lauren Buzzeo         87.739510
# Michael Schachner     86.907493
# Fiona Adams           86.888889
# Susan Kostrzewa       86.609217
# Carrie Dykes          86.395683
# Alexander Peartree    85.855422
# Name: points, dtype: float64

# %%
df.groupby('taster_name')['points'].mean().sort_values(ascending = False).plot(kind = 'bar', figsize = (9, 5), title = 'Tasters Scores', color = 'blue') 
plt.ylim (80, 93)
# Out:
# (80, 93)
